# %%
cd /content/drive/MyDrive/IDM_Project/idm-data-project/
# Out:
# /content/drive/MyDrive/IDM_Project/idm-data-project

# %%
import os
from getpass import getpass
import urllib

user = input('User name: ')
password = getpass('Password: ')
password = urllib.parse.quote(password) # password is converted into url format
repo_name = input('Repo name: ')

cmd_string = 'git clone https://{0}:{1}@github.com/makfordead/{2}.git'.format(user, password, repo_name)

os.system(cmd_string)
cmd_string, password = "", "" # removing the password from the variable
# Out:
# User name: Murtaza-Kazmi
# Password: ··········
# Repo name: idm-data-project

# %%
# !git add .
# !git commit -m "divided into basic components and imported files. ready for data understanding"
# !git push
# Out:
# [main 4b897b2] added code file on colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 code.ipynb
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.40 KiB | 719.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/makfordead/idm-data-project.git
#    2b7afb4..4b897b2  main -> main

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('allbp-data.csv')

# %% [markdown]
# # Data Understanding

# %%
df.describe()
# Out:
#          age   sex on thyroxine  ...   TBG referral source           class
# count   2800  2800         2800  ...  2800            2800            2800
# unique    94     3            2  ...     1               5            2800
# top       59     F            f  ...     ?           other  negative.|2464
# freq      75  1830         2470  ...  2800            1632               1
#
# [4 rows x 30 columns]

# %%
df.head(10)
# Out:
#   age sex on thyroxine  ... TBG referral source           class
# 0  41   F            f  ...   ?            SVHC  negative.|3733
# 1  23   F            f  ...   ?           other  negative.|1442
# 2  46   M            f  ...   ?           other  negative.|2965
# 3  70   F            t  ...   ?           other   negative.|806
# 4  70   F            f  ...   ?             SVI  negative.|2807
# 5  18   F            t  ...   ?           other  negative.|3434
# 6  59   F            f  ...   ?           other  negative.|1595
# 7  80   F            f  ...   ?             SVI  negative.|1367
# 8  66   F            f  ...   ?             SVI  negative.|1787
# 9  68   M            f  ...   ?             SVI  negative.|2534
#
# [10 rows x 30 columns]

# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Modelling

# %% [markdown]
# # Evaluation
