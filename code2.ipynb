# %%
cd /content/drive/MyDrive/IDM_Project/idm-data-project/
# Out:
# /content/drive/MyDrive/IDM_Project/idm-data-project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from getpass import getpass
import urllib

user = input('User name: ')
password = getpass('Password: ')
password = urllib.parse.quote(password) # password is converted into url format
repo_name = input('Repo name: ')

cmd_string = 'git pull https://{0}:{1}@github.com/makfordead/{2}.git'.format(user, password, repo_name)

os.system(cmd_string)
cmd_string, password = "", "" # removing the password from the variable
# Out:
# User name: makfordead
# Password: ··········

# %%
# !git config --global user.email "murtaza.kazmi.75@gmail.com"
# !git config --global user.name "Murtaza-Kazmi"

# %%
# !git add .
# !git commit -m "done and dusted - che"
# !git push

# %% [markdown]
# # Imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('allbp-data.csv')
test = pd.read_csv('allbp-test.csv')

# %% [markdown]
# # Data Understanding

# %%
df.describe()
# Out:
#          age   sex on thyroxine  ...   TBG referral source          class
# count   2800  2800         2800  ...  2800            2800           2800
# unique    94     3            2  ...     1               5           2800
# top       59     F            f  ...     ?           other  negative.|652
# freq      75  1830         2470  ...  2800            1632              1
#
# [4 rows x 30 columns]

# %%
df.head(10)
# Out:
#   age sex on thyroxine  ... TBG referral source           class
# 0  41   F            f  ...   ?            SVHC  negative.|3733
# 1  23   F            f  ...   ?           other  negative.|1442
# 2  46   M            f  ...   ?           other  negative.|2965
# 3  70   F            t  ...   ?           other   negative.|806
# 4  70   F            f  ...   ?             SVI  negative.|2807
# 5  18   F            t  ...   ?           other  negative.|3434
# 6  59   F            f  ...   ?           other  negative.|1595
# 7  80   F            f  ...   ?             SVI  negative.|1367
# 8  66   F            f  ...   ?             SVI  negative.|1787
# 9  68   M            f  ...   ?             SVI  negative.|2534
#
# [10 rows x 30 columns]

# %%
test.head()
# Out:
#    age sex on thyroxine  ... TBG referral source           class
# 0   35   F            f  ...   ?           other   negative.|219
# 1   63   M            f  ...   ?             SVI  negative.|2059
# 2   25   F            f  ...   ?            SVHD   negative.|399
# 3   53   F            f  ...   ?           other  negative.|1911
# 4   92   F            f  ...   ?             SVI   negative.|487
#
# [5 rows x 30 columns]

# %%
test.describe()
# Out:
#               age
# count  972.000000
# mean    51.423868
# std     18.966700
# min      7.000000
# 25%     35.000000
# 50%     54.000000
# 75%     67.000000
# max     93.000000

# %% [markdown]
# # Data Preparation

# %%
df['class'] = df['class'].apply(lambda x: x[:x.find('.')])
test['class'] = test['class'].apply(lambda x: x[:x.find('.')])

# %%
test.head(10)
# Out:
#    age sex on thyroxine  ... TBG referral source     class
# 0   35   F            f  ...   ?           other  negative
# 1   63   M            f  ...   ?             SVI  negative
# 2   25   F            f  ...   ?            SVHD  negative
# 3   53   F            f  ...   ?           other  negative
# 4   92   F            f  ...   ?             SVI  negative
# 5   67   M            f  ...   ?           other  negative
# 6   60   F            f  ...   ?           other  negative
# 7   60   F            f  ...   ?             SVI  negative
# 8   48   F            f  ...   ?           other  negative
# 9   27   F            f  ...   ?             SVI  negative
#
# [10 rows x 30 columns]

# %%
df.head(10)
# Out:
#   age sex on thyroxine  ... TBG referral source     class
# 0  41   F            f  ...   ?            SVHC  negative
# 1  23   F            f  ...   ?           other  negative
# 2  46   M            f  ...   ?           other  negative
# 3  70   F            t  ...   ?           other  negative
# 4  70   F            f  ...   ?             SVI  negative
# 5  18   F            t  ...   ?           other  negative
# 6  59   F            f  ...   ?           other  negative
# 7  80   F            f  ...   ?             SVI  negative
# 8  66   F            f  ...   ?             SVI  negative
# 9  68   M            f  ...   ?             SVI  negative
#
# [10 rows x 30 columns]

# %%
df.dropna().count()

# %%
# df = pd.read_csv('allbp-data.csv')
# test = pd.read_csv('allbp-test.csv')

# %%
df['TBG'].unique()
# Out:
# array(['?'], dtype=object)

# %%
test['TBG'].unique()
# Out:
# array(['?'], dtype=object)

# %%
df.drop(columns='TBG', inplace = True)
test.drop(columns='TBG', inplace = True)

# %%
# for col in df.columns:
#     df.drop(df[df[col] == '?'].index, inplace = True)

# %%
# for col in test.columns:
#     test.drop(test[test[col] == '?'].index, inplace = True)

# %%
df.describe()
# Out:
#          age   sex on thyroxine  ... TBG measured referral source     class
# count   2800  2800         2800  ...         2800            2800      2800
# unique    94     3            2  ...            1               5         3
# top       59     F            f  ...            f           other  negative
# freq      75  1830         2470  ...         2800            1632      2667
#
# [4 rows x 29 columns]

# %%
for col in df.columns:
  df[col] = df[col].apply(lambda x: np.nan if (x=="?") else x)
df.describe()
# Out:
#          age   sex on thyroxine  ... TBG measured referral source     class
# count   2799  2690         2800  ...         2800            2800      2800
# unique    93     2            2  ...            1               5         3
# top       59     F            f  ...            f           other  negative
# freq      75  1830         2470  ...         2800            1632      2667
#
# [4 rows x 29 columns]

# %%
for col in test.columns:
  test[col] = test[col].apply(lambda x: np.nan if (x=="?") else x)
test.describe()
# Out:
#               age
# count  972.000000
# mean    51.423868
# std     18.966700
# min      7.000000
# 25%     35.000000
# 50%     54.000000
# 75%     67.000000
# max     93.000000

# %%
df.describe()["age"].top
# Out:
# '59'

# %%
df.head()
# Out:
#   age sex on thyroxine  ... TBG measured referral source     class
# 0  41   F            f  ...            f            SVHC  negative
# 1  23   F            f  ...            f           other  negative
# 2  46   M            f  ...            f           other  negative
# 3  70   F            t  ...            f           other  negative
# 4  70   F            f  ...            f             SVI  negative
#
# [5 rows x 29 columns]

# %%
cat_val = ['sex','on thyroxine','query on thyroxine','on antithyroid medication','sick','pregnant','thyroid surgery','I131 treatment','query hypothyroid','query hyperthyroid','lithium','goitre','tumor','hypopituitary','psych','TSH measured','T3 measured',
           'TT4 measured','T4U measured','FTI measured', "TBG measured", "referral source"]
for col in df.columns:
  if col in cat_val and col != 'class':
    mode = df.describe()[col].top
    print(mode)
    df[col] = df[col].fillna(mode)
  
# print(missing_categories)
# Out:
# F
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# t
# t
# t
# t
# t
# f
# other

# %%
test.head()
# Out:
#    age sex on thyroxine  ... TBG measured referral source     class
# 0   35   F            f  ...            f           other  negative
# 1   63   M            f  ...            f             SVI  negative
# 2   25   F            f  ...            f            SVHD  negative
# 3   53   F            f  ...            f           other  negative
# 4   92   F            f  ...            f             SVI  negative
#
# [5 rows x 29 columns]

# %%
test.describe()
# Out:
#               age
# count  972.000000
# mean    51.423868
# std     18.966700
# min      7.000000
# 25%     35.000000
# 50%     54.000000
# 75%     67.000000
# max     93.000000

# %%
test.columns
# Out:
# Index(['age', 'sex', 'on thyroxine', 'query on thyroxine',
#        'on antithyroid medication', 'sick', 'pregnant', 'thyroid surgery',
#        'I131 treatment', 'query hypothyroid', 'query hyperthyroid', 'lithium',
#        'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH measured', 'TSH',
#        'T3 measured', 'T3', 'TT4 measured', 'TT4', 'T4U measured', 'T4U',
#        'FTI measured', 'FTI', 'TBG measured', 'referral source', 'class'],
#       dtype='object')

# %%
for col in test.columns:
  if col in cat_val and col != 'class':
    mode = test[col].mode()
    print(mode)
    test[col] = test[col].fillna(mode)
# Out:
# 0    F
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    f
# dtype: object
# 0    t
# dtype: object
# 0    t
# dtype: object
# 0    t
# dtype: object
# 0    t
# dtype: object
# 0    t
# dtype: object
# 0    f
# dtype: object
# 0    other
# dtype: object

# %%
df.head()
# Out:
#   age sex on thyroxine  ... TBG measured referral source     class
# 0  41   F            f  ...            f            SVHC  negative
# 1  23   F            f  ...            f           other  negative
# 2  46   M            f  ...            f           other  negative
# 3  70   F            t  ...            f           other  negative
# 4  70   F            f  ...            f             SVI  negative
#
# [5 rows x 29 columns]

# %%
mean = df.mean()

# %%
mean
# Out:
# Series([], dtype: float64)

# %%
df.head(200)
# Out:
#     age sex  ... referral source                      class
# 0    41   F  ...            SVHC                   negative
# 1    23   F  ...           other                   negative
# 2    46   M  ...           other                   negative
# 3    70   F  ...           other                   negative
# 4    70   F  ...             SVI                   negative
# ..   ..  ..  ...             ...                        ...
# 195  45   M  ...           other                   negative
# 196  71   F  ...           other                   negative
# 197  83   M  ...           other  increased binding protein
# 198  35   F  ...           other                   negative
# 199  32   F  ...           other  increased binding protein
#
# [200 rows x 29 columns]

# %%
for col in df.columns:
  if (not col in cat_val) and col != 'class':
    print(col)
# Out:
# age
# TSH
# T3
# TT4
# T4U
# FTI

# %%
cat_val = ['sex','on thyroxine','query on thyroxine','on antithyroid medication','sick','pregnant','thyroid surgery','I131 treatment','query hypothyroid','query hyperthyroid','lithium','goitre','tumor','hypopituitary','psych','TSH measured','T3 measured',
           'TT4 measured','T4U measured','FTI measured', "TBG measured", "referral source"]
for col in df.columns:
  if (not col in cat_val) and col != 'class':
    mean = pd.to_numeric(df[col]).mean()
    print(mean)
    df[col] = df[col].fillna(mean)
# print(missing_categories)
# Out:
# 51.8442300821722
# 4.672150238473764
# 2.0249661399548584
# 109.07240061162081
# 0.9979121054734302
# 110.78798403193613

# %%
for col in test.columns:
  if (not col in cat_val) and col != 'class':
    mean = pd.to_numeric(test[col]).mean()
    print(mean)
    test[col] = test[col].fillna(mean)
# print(missing_categories)
# Out:
# 51.4238683127572
# 6.262835400225488
# 1.9812690355329952
# 106.18962162162161
# 0.9867346938775513
# 109.56553287981859

# %%
df.head()
# Out:
#   age sex on thyroxine  ... TBG measured referral source     class
# 0  41   F            f  ...            f            SVHC  negative
# 1  23   F            f  ...            f           other  negative
# 2  46   M            f  ...            f           other  negative
# 3  70   F            t  ...            f           other  negative
# 4  70   F            f  ...            f             SVI  negative
#
# [5 rows x 29 columns]

# %%
df.head()
df.describe()
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# on thyroxine                 0
# query on thyroxine           0
# on antithyroid medication    0
# sick                         0
# pregnant                     0
# thyroid surgery              0
# I131 treatment               0
# query hypothyroid            0
# query hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# TSH measured                 0
# TSH                          0
# T3 measured                  0
# T3                           0
# TT4 measured                 0
# TT4                          0
# T4U measured                 0
# T4U                          0
# FTI measured                 0
# FTI                          0
# TBG measured                 0
# referral source              0
# class                        0
# dtype: int64

# %%
print(972-696, "decreased from test data which originally had 972. Now 696")
# Out:
# 276 decreased from test data which originally had 972. Now 696

# %%
test.head()
# Out:
#    age sex on thyroxine  ... TBG measured referral source     class
# 1   63   M            f  ...            f             SVI  negative
# 2   25   F            f  ...            f            SVHD  negative
# 3   53   F            f  ...            f           other  negative
# 4   92   F            f  ...            f             SVI  negative
# 6   60   F            f  ...            f           other  negative
#
# [5 rows x 29 columns]

# %%
X = df.drop(columns='class')

# %%
X_test = test.drop(columns='class')

# %%
X.head()
# Out:
#   age sex on thyroxine  ...      FTI TBG measured referral source
# 0  41   F            f  ...      109            f            SVHC
# 1  23   F            f  ...  110.788            f           other
# 2  46   M            f  ...      120            f           other
# 3  70   F            t  ...  110.788            f           other
# 4  70   F            f  ...       70            f             SVI
#
# [5 rows x 28 columns]

# %%
for col in X.columns:
  if not col in ['sex','age', 'TSH', 'T3', 'TT4', 'T4U', 'FTI', 'TBG', 'referral source']:
    X[col] = X[col].apply(lambda x: 1 if x.lower() == 'f' else '0')

X['sex'] = X['sex'].apply(lambda x: 1 if x.lower() == 'F' else '0')

# %%
X['referral source'].unique()
# Out:
# array(['SVHC', 'other', 'SVI', 'STMW', 'SVHD'], dtype=object)

# %%
X['referral source'] = X['referral source'].apply(lambda x: 0 if x == 'SVHC' else (1 if x == 'other' else (2 if x == 'SVI' else (3 if x == 'STMW' else 4))))

# %%
for col in X_test.columns:
  if not col in ['sex','age', 'TSH', 'T3', 'TT4', 'T4U', 'FTI', 'TBG', 'referral source']:
    X_test[col] = X_test[col].apply(lambda x: 1 if x.lower() == 'f' else '0')

X_test['sex'] = X_test['sex'].apply(lambda x: 1 if x == 'F' else '0')

# %%
X_test['referral source'].unique()
# Out:
# array(['other', 'SVI', 'SVHD', 'SVHC', 'STMW'], dtype=object)

# %%
X_test['referral source'] = X_test['referral source'].apply(lambda x: 0 if x == 'SVHC' else (1 if x == 'other' else (2 if x == 'SVI' else (3 if x == 'STMW' else 4))))

# %%
X.head()
# Out:
#   age sex on thyroxine  ...      FTI TBG measured referral source
# 0  41   0            1  ...      109            1               0
# 1  23   0            1  ...  110.788            1               1
# 2  46   0            1  ...      120            1               1
# 3  70   0            0  ...  110.788            1               1
# 4  70   0            1  ...       70            1               2
#
# [5 rows x 28 columns]

# %%
X_test.head()
# Out:
#    age sex on thyroxine  ...      FTI TBG measured referral source
# 0   35   1            1  ...  109.566            1               1
# 1   63   0            1  ...      113            1               2
# 2   25   1            1  ...       75            1               4
# 3   53   1            1  ...      141            1               1
# 4   92   1            1  ...      143            1               2
#
# [5 rows x 28 columns]

# %%
X_train = X

# %%
y = df['class']

# %%
y = y.apply(lambda x: 0 if x == 'negative' else (1 if x == 'increased binding protein' else 2))

# %%
y_train = y

# %%
y_test = test['class']

# %%
y_test = y_test.apply(lambda x: 0 if x == 'negative' else (1 if x == 'increased binding protein' else 2))

# %%
y_train.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class, dtype: int64

# %%
y_test.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class, dtype: int64

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1, test_size = 0.3, shuffle=False)

# %% [markdown]
# # Modelling

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import re
import spacy
from gensim.parsing.preprocessing import remove_stopwords
import gensim

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import ComplementNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import CategoricalNB
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RepeatedStratifiedKFold
from scipy.stats import loguniform

 
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # MultinomialNB

# %%
nb = MultinomialNB()
nb.fit(X_train, y_train)
nb_pred = nb.predict(X_test)
accuracy_score(y_test, nb_pred)
# Out:
# 0.7448559670781894

# %%
model = MultinomialNB()
space = dict()
space['alpha'] = [i for i in range(1, 1000, 10)]
# define search
search = GridSearchCV(model, space, scoring='accuracy', n_jobs=-1)
# execute search
result = search.fit(X_train, y_train)
# summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.95
# Best Hyperparameters: {'alpha': 871}

# %%
print("Classification Report:")
logistic_class_report = classification_report(y_test, result.predict(X_test))
print(logistic_class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       942
#            1       0.00      0.00      0.00        25
#            2       0.00      0.00      0.00         5
#
#     accuracy                           0.96       972
#    macro avg       0.32      0.33      0.33       972
# weighted avg       0.94      0.96      0.95       972
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # BernoulliNB

# %%
model = BernoulliNB()
space = dict()
space['alpha'] = [0.1, 0.2, 0.5, 0.8, 1.0, 1.2, 1.4, 1.6, 2.0, 2.2, 2.4, 2.6, 2.8,3.0, 3.1,3.2,3.3,3.4]
# define search
search = GridSearchCV(model, space, scoring='accuracy', n_jobs=-1)
# execute search
result = search.fit(X_train, y_train)
# summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.9517210467339001
# Best Hyperparameters: {'alpha': 0.8}

# %% [markdown]
# # ComplementNB

# %%
model = ComplementNB()
space = dict()
space['alpha'] = [0.1,0.15,0.17, 0.19, 0.2,0.21,0.22, 0.23, 0.24,0.25,0.27, 0.28, 0.29,0.3, 0.5, 0.8, 1.0, 1.2, 1.4, 1.6, 2.0,2.1, 2.2, 2.4, 2.6, 2.8,2.9,3.0, 3.1, 3.2, 3.4, 3.6, 3.8, 3.9,4.0, 4.1, 4.2, 4.3, 4.4, 4.6, 4.8,4.9,5.0,5.1,5.2,5.3, 5.4, 5.5, 5.6, 5.7, 6, 6.4, 6.8, 7.2, 7.4, 7.8, 8.2]
# define search
search = GridSearchCV(model, space, scoring='accuracy', n_jobs=-1)
# execute search
result = search.fit(X_train, y_train)
# summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.781203612154769
# Best Hyperparameters: {'alpha': 8.2}

# %%
print("Classification Report:")
logistic_class_report = classification_report(y_test, result.predict(X_test))
print(logistic_class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.78      0.87       674
#            1       0.10      0.89      0.17        18
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.78       696
#    macro avg       0.36      0.56      0.35       696
# weighted avg       0.96      0.78      0.85       696
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
nb_pred = nb.predict(X_test)
accuracy_score(y_test, nb_pred)
# Out:
# 0.1724137931034483

# %%
print("Classification Report:")
logistic_class_report = classification_report(y_test, nb.predict(X_test))
print(logistic_class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.15      0.26       674
#            1       0.10      0.78      0.18        18
#            2       0.01      1.00      0.02         4
#
#     accuracy                           0.17       696
#    macro avg       0.37      0.64      0.15       696
# weighted avg       0.96      0.17      0.26       696

# %% [markdown]
# # CategoricalNB

# %%
model = CategoricalNB()
space = dict()
space['alpha'] = [0.1,0.15,0.17, 0.19, 0.2,0.21,0.22, 0.23, 0.24,0.25,0.27, 0.28, 0.29,0.3, 0.5, 0.8, 1.0, 1.2, 1.4, 1.6, 2.0,2.1, 2.2, 2.4, 2.6, 2.8,2.9,3.0, 3.1, 3.2, 3.4, 3.6, 3.8, 3.9,4.0, 4.1, 4.2, 4.3, 4.4, 4.6, 4.8,4.9,5.0,5.1,5.2,5.3, 5.4, 5.5, 5.6, 5.7, 6, 6.4, 6.8, 7.2, 7.4, 7.8, 8.2]
# define search
search = GridSearchCV(model, space, scoring='accuracy', n_jobs=-1)
# execute search
result = search.fit(X_train, y_train)
# summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     r = call_item()
#   File "/usr/local/lib/python3.6/dist-packages/joblib/externals/loky/process_executor.py", line 285, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/usr/local/lib/python3.6/dist-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
# ...

# %%
print("Classification Report:")
logistic_class_report = classification_report(y_test, result.predict(X_test))
print(logistic_class_report)

# %% [markdown]
# # Random Forest and Gradient Boosted Trees

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 1000,10)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy','gini']}
print(random_grid)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
rf=RandomForestClassifier()

# %%
rf_randomcv=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=100,cv=5,verbose=2,
                               random_state=100,n_jobs=-1)
### fit the randomized model
rf_randomcv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed: 16.5min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
# ...

# %%
rf_randomcv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 230,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 1400}

# %%
best_random_grid=rf_randomcv.best_estimator_

# %%
y_pred=best_random_grid.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
print("Classification report: {}".format(classification_report(y_test,y_pred)))
# Out:
# [[665   9   0]
#  [  5  13   0]
#  [  4   0   0]]
# Accuracy Score 0.9741379310344828
# Classification report:               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       674
#            1       0.59      0.72      0.65        18
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.97       696
#    macro avg       0.53      0.57      0.55       696
# weighted avg       0.97      0.97      0.97       696
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
param_grid = {
    'criterion': [rf_randomcv.best_params_['criterion']],
    'max_depth': [rf_randomcv.best_params_['max_depth']],
    'max_features': [rf_randomcv.best_params_['max_features']],
    'min_samples_leaf': [rf_randomcv.best_params_['min_samples_leaf'], 
                         rf_randomcv.best_params_['min_samples_leaf']+2, 
                         rf_randomcv.best_params_['min_samples_leaf'] + 4],
    'min_samples_split': [rf_randomcv.best_params_['min_samples_split'] - 2,
                          rf_randomcv.best_params_['min_samples_split'] - 1,
                          rf_randomcv.best_params_['min_samples_split'], 
                          rf_randomcv.best_params_['min_samples_split'] +1,
                          rf_randomcv.best_params_['min_samples_split'] + 2],
    'n_estimators': [rf_randomcv.best_params_['n_estimators'] - 200, rf_randomcv.best_params_['n_estimators'] - 100, 
                     rf_randomcv.best_params_['n_estimators'], 
                     rf_randomcv.best_params_['n_estimators'] + 100, rf_randomcv.best_params_['n_estimators'] + 200]
}

print(param_grid)
# Out:
# {'criterion': ['gini'], 'max_depth': [230], 'max_features': ['sqrt'], 'min_samples_leaf': [1, 3, 5], 'min_samples_split': [0, 1, 2, 3, 4], 'n_estimators': [1200, 1300, 1400, 1500, 1600]}

# %%
rf=RandomForestClassifier()
grid_search=GridSearchCV(estimator=rf,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 75 candidates, totalling 750 fits
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 644 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 750 out of 750 | elapsed: 22.0min finished
# GridSearchCV(cv=10, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
# ...

# %%
best_grid=grid_search.best_estimator_
print(best_grid)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=230, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1300,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred=best_grid.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
print("Classification report: {}".format(classification_report(y_test,y_pred)))
# Out:
# [[666   8   0]
#  [  5  13   0]
#  [  4   0   0]]
# Accuracy Score 0.9755747126436781
# Classification report:               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       674
#            1       0.62      0.72      0.67        18
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.98       696
#    macro avg       0.54      0.57      0.55       696
# weighted avg       0.97      0.98      0.97       696
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
rf=RandomForestClassifier()
grid_search=GridSearchCV(estimator=rf,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(X_train,y_train)

# %%
#Gradient Boosting

gb = GradientBoostingClassifier(n_estimators=1000, learning_rate=0.24)
gb.fit(X_train, y_train)
gb_pred = gb.predict(X_test)
accuracy_score(y_test, gb_pred)
# Out:
# 0.978448275862069

# %% [markdown]
# # Experiment

# %%
import seaborn as sns
import warnings
from sklearn import linear_model, tree, discriminant_analysis, naive_bayes, ensemble, gaussian_process
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, cross_val_score, GridSearchCV
from sklearn.metrics import log_loss, confusion_matrix
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100)

# %%
classifiers = [

    #GLM
    linear_model.LogisticRegressionCV(),

    #Navies Bayes
    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),

    #Discriminant Analysis
    discriminant_analysis.LinearDiscriminantAnalysis(),
    discriminant_analysis.QuadraticDiscriminantAnalysis(),

    #Ensemble Methods
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(),
    ensemble.ExtraTreesClassifier(),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(),

    #Gaussian Processes
    gaussian_process.GaussianProcessClassifier(),

    #xgboost: http://xgboost.readthedocs.io/en/latest/model.html
#     xgb.XGBClassifier()    
]

# %%
def find_best_algorithms(classifier_list, X, y):
    # This function is adapted from https://www.kaggle.com/yassineghouzam/titanic-top-4-with-ensemble-modeling
    # Cross validate model with Kfold stratified cross validation
    kfold = StratifiedKFold(n_splits=5)

    # Grab the cross validation scores for each algorithm
    cv_results = [cross_val_score(classifier, X, y, scoring = "neg_log_loss", cv = kfold) for classifier in classifier_list]
    cv_means = [cv_result.mean() * -1 for cv_result in cv_results]
    cv_std = [cv_result.std() for cv_result in cv_results]
    algorithm_names = [alg.__class__.__name__ for alg in classifiers]

    # Create a DataFrame of all the CV results
    cv_results = pd.DataFrame({
        "Mean Log Loss": cv_means,
        "Log Loss Std": cv_std,
        "Algorithm": algorithm_names
    }).sort_values(by='Mean Log Loss')
    return cv_results

# %%
algorithm_results = find_best_algorithms(classifiers, X, y)

# %%
print(algorithm_results)

# %% [markdown]
# # Evaluation
